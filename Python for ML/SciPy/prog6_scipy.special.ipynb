# %%
import numpy as np 
import scipy.special as special

# %%
num = int(input("Enter a number: "))
print("Cube Root:", special.cbrt(num))
# Out:
# Cube Root: 5.0

# %%
print("Cube Root " , special.cbrt(np.array([64,125,729])))
# Out:
# Cube Root  [4. 5. 9.]
